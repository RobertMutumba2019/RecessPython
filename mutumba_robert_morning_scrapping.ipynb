# %%
import csv
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
URL='https://xeno-canto.org/'
headers={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"}
page=requests.get(URL,headers=headers)
soup1=BeautifulSoup(page.content,'html.parser')

soup2=BeautifulSoup(soup1.prettify(),'html.parser')
print(soup2)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>
#    xeno-canto :: Sharing wildlife sounds from around the world
#   </title>
# <meta charset="utf-8"/>
# <meta content="index,follow" name="robots"/>
# <meta content="bird songs, bird sounds, grasshopper sounds, wildlife sounds, birds, grasshoppers, bird sound recordings, bird song recordings, bird song archive, bird sound archive, grasshopper sounds, xeno-canto" name="keywords"/>
# <link href="/static/img/favicon.png" rel="icon" type="image/png"/>
# <link href="/static/img/favicon-60.png" rel="apple-touch-icon" type="image/png"/>
# <link href="/static/img/favicon-76.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/>
# <link href="/static/img/favicon-120.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/>
# <link href="/static/img/favicon-152.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/>
# <link href="/static/js/jquery.fancybox.css?v3-0-1" rel="stylesheet" type="text/css"/>
# <link href="/static/js/jquery.qtip.min.css?v3-0-1" rel="stylesheet" type="text/css"/>
# <link href="/static/js/jplayer/xcplayer.css?v3-0-1" rel="stylesheet" type="text/css"/>
# <link href="/static/css/xeno-canto.css?v3-0-1" rel="stylesheet" type="text/css"/>
# <link href="//fonts.googleapis.com/css?family=Ubuntu:400,700|Ubuntu+Condensed" rel="stylesheet" type="text/css"/>
# <!-- this needs to be in the header -->
# <!-- <script type='text/javascript' src='//ajax.googleapis.com/ajax/libs/jquery/1.6/jquery.min.js'></script> -->
# <script src="https://code.jquery.com/jquery-1.12.4.min.js">
# </script>
# <script src="https://code.jquery.com/jquery-migrate-1.4.1.min.js ">
# </script>
# <!--[if lt IE 9]>
#             <script>
#                 document.createElement('header');
#                 document.createElement('nav');
#                 document.createElement('section');
#                 document.createElement('article');
#                 document.createElement('aside');
#                 document.createElement('footer');
#                 document.createElement('hgroup');
#                 document.createElement('figure');
#                 document.createElement('figcaption');
#             </script>
#             <![endif]-->
# </head>
# <body id="">
# <header class="">
# <div id="banner">
# <hgroup id="logo">
# <h1>
# <a href="https://xeno-canto.org/">
#        xeno-canto
#       </a>
# </h1>
# <h2>
#       Sharing wildlife sounds from around the world
#      </h2>
# </hgroup>
# <script type="text/javascript">
#      function showSpeciesNr(value, data)
#         {
#             jQuery('#species_nr').val(data.species_nr);
#             jQuery('#quick-search-bar > form').submit();
#         }
#     </script>
# <div id="quick-search-bar">
# <form action="https://xeno-canto.org/explore" autocomplete="off" class="species-completion" method="post">
# <input id="species_nr" name="species_nr" type="hidden" value=""/>
# <div class="search-box">
# <input class="species-input" data-onselect="showSpeciesNr" id="quick-search-input" name="query" placeholder="Search recordings..." type="text" value=""/>
# <input type="submit" value="Search"/>
# </div>
# </form>
# <div class="search-help">
# <ul class="simple">
# <li>
# <a href="https://xeno-canto.org/search">
#          Advanced Search
#         </a>
# </li>
# <li>
# <a class="tooltip" data-qtip-content="&lt;table class='key-value'&gt;
#             &lt;tr&gt;&lt;td&gt;grp:&lt;/td&gt;&lt;td&gt;Group&lt;/td&gt;&lt;/tr&gt;
#             &lt;tr&gt;&lt;td&gt;gen:&lt;/td&gt;&lt;td&gt;Genus&lt;/td&gt;&lt;/tr&gt;
#             &lt;tr&gt;&lt;td&gt;ssp:&lt;/td&gt;&lt;td&gt;Subspecies&lt;/td&gt;&lt;/tr&gt;
#             &lt;tr&gt;&lt;td&gt;rec:&lt;/td&gt;&lt;td&gt;Recordist&lt;/td&gt;&lt;/tr&gt;
#             &lt;tr&gt;&lt;td&gt;cnt:&lt;/td&gt;&lt;td&gt;Country&lt;/td&gt;&lt;/tr&gt;
#             &lt;tr&gt;&lt;td&gt;loc:&lt;/td&gt;&lt;td&gt;Location&lt;/td&gt;&lt;/tr&gt;
#             &lt;tr&gt;&lt;td&gt;rmk:&lt;/td&gt;&lt;td&gt;Recordist remarks&lt;/td&gt;&lt;/tr&gt;
#             &lt;tr&gt;&lt;td&gt;seen:&lt;/td&gt;&lt;td&gt;Animals seen&lt;/td&gt;&lt;/tr&gt;
#             &lt;tr&gt;&lt;td&gt;playback:&lt;/td&gt;&lt;td&gt;Playback used&lt;/td&gt;&lt;/tr&gt;
#             &lt;tr&gt;&lt;td&gt;also:&lt;/td&gt;&lt;td&gt;Background species&lt;/td&gt;&lt;/tr&gt;
#             &lt;tr&gt;&lt;td&gt;type:&lt;/td&gt;&lt;td&gt;Predefined sound type&lt;/td&gt;&lt;/tr&gt;
#             &lt;tr&gt;&lt;td&gt;sex:&lt;/td&gt;&lt;td&gt;Sex&lt;/td&gt;&lt;/tr&gt;
#             &lt;tr&gt;&lt;td&gt;stage:&lt;/td&gt;&lt;td&gt;Life stage&lt;/td&gt;&lt;/tr&gt;
#             &lt;tr&gt;&lt;td&gt;method:&lt;/td&gt;&lt;td&gt;Recording method&lt;/td&gt;&lt;/tr&gt;
#             &lt;tr&gt;&lt;td&gt;nr:&lt;/td&gt;&lt;td&gt;XC number&lt;/td&gt;&lt;/tr&gt;
#             &lt;tr&gt;&lt;td&gt;lic:&lt;/td&gt;&lt;td&gt;Recording license&lt;/td&gt;&lt;/tr&gt;
#             &lt;tr&gt;&lt;td&gt;q:&lt;/td&gt;&lt;td&gt;Recording quality&lt;/td&gt;&lt;/tr&gt;
#             &lt;tr&gt;&lt;td&gt;len:&lt;/td&gt;&lt;td&gt;Recording length (in s)&lt;/td&gt;&lt;/tr&gt;
#             &lt;tr&gt;&lt;td colspan='2' style='padding-top: 8px;'&gt;&lt;a href='https://xeno-canto.org/help/search'&gt;All options explained...&lt;/a&gt;&lt;/td&gt;&lt;/tr&gt;
#             &lt;/table&gt;" data-qtip-header="Quick Search Reference" href="https://xeno-canto.org/help/search">
#          Tips
#         </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <nav id="main-menu">
# <table>
# <tr>
# <td>
# <ul class="sf-menu">
# <li>
#          About
#          <img class="icon" height="14" src="/static/img/down.png" width="14"/>
# <ul>
# <li>
# <a href="https://xeno-canto.org/about/xeno-canto">
#             About xeno-canto
#            </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/collection/">
#             Collection Details
#            </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/explore/api">
#             API
#            </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/contributors">
#             Meet the Members
#            </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/help/FAQ">
#             Frequently Asked Questions
#            </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/about/terms">
#             Terms of Use
#            </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/about/credits">
#             Credits &amp; Colofon
#            </a>
# </li>
# </ul>
# </li>
# <li>
#          Explore
#          <img class="icon" height="14" src="/static/img/down.png" width="14"/>
# <ul>
# <li>
# <a href="https://xeno-canto.org/explore/region">
#             By Region
#             <li>
# <a href="https://xeno-canto.org/explore/taxonomy">
#               By Taxonomy
#              </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/explore?query=since:31&amp;dir=0&amp;order=xc">
#               Recent Recordings
#              </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/explore/random">
#               Random Recordings
#              </a>
# </li>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://xeno-canto.org/upload">
#           Upload Sounds
#          </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/forum/">
#           Forum
#          </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/mysteries">
#           Mysteries
#          </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/articles">
#           Articles
#          </a>
# </li>
# </ul>
# </td>
# <td style="white-space: nowrap; text-align: right">
# <ul class="sf-menu right">
# <li>
# <a href="https://xeno-canto.org/auth/login">
#           Log in / Register
#          </a>
# </li>
# </ul>
# </td>
# </tr>
# </table>
# </nav>
# </header>
# <div id="content-area">
# <noscript>
# <div class="warning">
# <b>
#       Note
#      </b>
#      : Many features of this site will not work without javascript
#     </div>
# </noscript>
# <div class="column" id="primary-content">
# <section class="spotlight">
# <a name="spotlight-147">
# </a>
# <h1>
# <a href="https://xeno-canto.org/collection/spotlight/147">
#        The bats are here!
#       </a>
# </h1>
# <figure>
# <img src="/graphics/spotlight/bat-roost-131015_400x300.jpg"/>
# <figcaption>
# <p>
#         Courtesy Gloriana Chaverri
#        </p>
# </figcaption>
# </figure>
# <div class="content">
# <div class="xc-audio">
# <div class="jp-type-single" data-xc-factor="10" data-xc-filepath="//xeno-canto.org/sounds/uploaded/CJSWMTHPKR/XC805313-T2014-02-10_22-16-00_0000040.mp3" data-xc-id="805313" id="xc_audio_805313_938">
# <div class="jp-xc-id">
# <table>
# <tr>
# <td>
# <a href="https://xeno-canto.org/805313">
#              XC805313
#             </a>
# <a href="https://xeno-canto.org/805313/download">
# <img height="14" src="/static/img/download.png" title="Download file 'XC805313 - Proboscis Bat - Rhynchonycteris naso.wav'" width="14"/>
# </a>
# </td>
# <td class="licenses">
# <a href="//creativecommons.org/licenses/by-nc-sa/4.0/" title="Creative Commons Attribution-NonCommercial-ShareAlike 4.0">
# <img height="14" src="/static/img/cc.png" width="14"/>
# <img height="14" src="/static/img/cc-by.png" width="14"/>
# <img height="14" src="/static/img/cc-nc.png" width="14">
# <img height="14" src="/static/img/cc-sa.png" width="14">
# </img>
# </img>
# </a>
# </td>
# </tr>
# </table>
# </div>
# <div class="jp-gui jp-interface">
# <ul class="jp-controls">
# <li>
# <a class="jp-play" href="javascript:;" tabindex="1">
#             play
#            </a>
# </li>
# <li>
# <a class="jp-pause" href="javascript:;" style="display:none;" tabindex="1">
#             pause
#            </a>
# </li>
# <li>
# <a class="jp-stop" href="javascript:;" tabindex="1">
#             stop
#            </a>
# </li>
# </ul>
# <div class="jp-progress">
# <div class="jp-seek-bar">
# <div class="jp-play-bar">
# </div>
# </div>
# </div>
# <div class="jp-time-holder">
# <div class="jp-current-time">
# </div>
# <div class="jp-xc-duration">
#            0:09
#           </div>
# </div>
# </div>
# <div class="jp-title" title="Proboscis Bat Rhynchonycteris naso - echolocation">
# <span class="common-name">
#           Proboscis Bat
#          </span>
#          (
#          <span class="sci-name">
#           Rhynchonycteris naso
#          </span>
#          ) ·
#          <span class="jp-xc-call-type">
#           echolocation
#          </span>
# </div>
# <div class="jp-xc-recordist">
#          Gloriana Chaverri
#         </div>
# </div>
# </div>
# <article>
# <p>
#         After the introduction of the Orthoptera, XC is now ready to expand to other groups. First up are the 1500 species of bats of the world!
# This new extensions was done with help from
#         <a href="https://www.batcr.com/">
#          Gloriana Chaverri
#         </a>
#         , bat expert from Costa Rica, and
#         <a href="https://marceloarayasalas.weebly.com/">
#          Marcelo Araya Salas
#         </a>
#         , an ecologist and bioacoustics expert we all know well from developing
#         <a href="https://cran.r-project.org/web/packages/warbleR/index.html">
#          WarbleR
#         </a>
#         , and generous financial support from
#         <a href="https://www.nlbif.nl/">
#          NLBIF
#         </a>
#         .
#        </p>
# <p>
#         XC focuses on sharing real-time recordings of bats, as explained in the
#         <a href="https://xeno-canto.org/help/FAQ#bats">
#          FAQ
#         </a>
#         .
# You can also learn there how to convert recordings from time-expanded to real-time.
#        </p>
# </article>
# </div>
# </section>
# <section id="whatisxc">
# <h1>
#       What is xeno-canto?
#      </h1>
# <p>
#       xeno-canto is a website dedicated to sharing wildlife sounds from all over the
#                 world. Whether you are a research scientist, a birder, or simply curious
#                 about a sound that you heard out your kitchen window, we invite you to
#                 listen, download, and explore the wildlife sound recordings in the collection.
#      </p>
# <p>
#       But xeno-canto is more than just a collection of recordings.  It is also a
#                 collaborative project. We invite you to share your own recordings, help
#                 identify mystery recordings, or share your expertise in the forums. Welcome!
#      </p>
# </section>
# <section class="column" id="news">
# <h1>
#       Latest News
#      </h1>
# <article>
# <footer>
#        July 22, 2023
#       </footer>
# <p>
# <p>
#         Steady trickle of bird species new to XC since april: Chestnut-headed Nunlet
#         <em>
#          Nonnula amaurocephala
#         </em>
#         by Gabriel Leite, White-quilled Rock Pigeon
#         <em>
#          Petrophassa albipennis
#         </em>
#         by Nick Talbot, Genovesa Ground Finch
#         <em>
#          Geospiza acutirostris
#         </em>
#         by Barry Edmonston, Vampire Ground Finch
#         <em>
#          Geospiza septentrionalis
#         </em>
#         by Dušan M. Brinkhuizen, Black-breasted Buttonquail
#         <em>
#          Turnix melanogaster
#         </em>
#         by Tom Tarrant, Long-billed Bush Warbler
#         <em>
#          Locustella major
#         </em>
#         by Andrew Spencer,
# Opalton Grasswren
#         <em>
#          Amytornis rowleyi
#         </em>
#         by Andrew Galbraith, White-breasted Ground Dove
#         <em>
#          Pampusana jobiensis
#         </em>
#         by Phil Gregory, Black-breasted Buzzard
#         <em>
#          Hamirostra melanosternon
#         </em>
#         by Dan Ashdown, Star-spotted Nightjar
#         <em>
#          Caprimulgus stellatus
#         </em>
#         by Adrian Hinkle, Jackson's Widowbird
#         <em>
#          Euplectes jacksoni
#         </em>
#         and Williams's Lark
#         <em>
#          Mirafra williamsi
#         </em>
#         by Brendan Sloan, Todd's Nightjar
#         <em>
#          Setopagis heterura)
#         </em>
#         by Marcelo Barreiros.
#         <a href="https://xeno-canto.org/collection/species/latest">
#          Check them out here
#         </a>
# </p>
# </p>
# <section class="comments">
# <article>
# <div>
# <p>
#           When I search for a bird like Garrulax canorus, it only has a legend without a play button or download link, and cannot link to the relevant location, which makes the search meaningless...
#          </p>
# </div>
# <footer>
#          HuangYaopei on July 28
#         </footer>
# </article>
# <article>
# <div>
# <p>
#           hi Huang Yaopei, yes,  that species is restricted, as are plenty of species in South-east Asia, a few hundred.  Please read the explanation that is linked from the species page.
#          </p>
# </div>
# <footer>
#          Willem-Pier Vellinga on July 28
#         </footer>
# </article>
# <p>
# <b>
#          2
#         </b>
#         replies ::
#         <img height="14" src="/static/img/discuss-light.png" width="14"/>
# <a href="https://xeno-canto.org/news/2106">
#          Your reply
#         </a>
# </p>
# </section>
# </article>
# <article>
# <footer>
#        June 22, 2023
#       </footer>
# <p>
# <p>
#         ... nice set by Marc Anderson from Nepal. Some rare recordings there. He also throws in the first bats from Australia. Cool.
#        </p>
# </p>
# <section class="comments">
# <article>
# <div>
# <p>
#           ... busy times and a few large sets recently. One by Gabriel Leite from Kenya for example, and now another by Peter Boesman from Kazakhstan and Kirgizstan. Meanwhile Marc Anderson has added more to that Nepal set. Great stuff. Also 400 species of Grasshoppers now with Daniel Parker adding a number from the US.
#          </p>
# </div>
# <footer>
#          Willem-Pier Vellinga on July  1
#         </footer>
# </article>
# <article>
# <div>
# <p>
#           Wow, I missed WP's addendum completely - thanks for the mention! My Orthoptera recordings are all amateur field recordings and most are not very good quality. But I enjoy contributing to the database of US Orthoptera sounds on this site, and I hope that more will join me in the future. I look forward to the day when the species coverage and the recording community here rival those of the birds!
#          </p>
# </div>
# <footer>
#          Daniel Parker on July  9
#         </footer>
# </article>
# <p>
# <b>
#          2
#         </b>
#         replies ::
#         <img height="14" src="/static/img/discuss-light.png" width="14"/>
# <a href="https://xeno-canto.org/news/2105">
#          Your reply
#         </a>
# </p>
# </section>
# </article>
# <article>
# <footer>
#        June  2, 2023
#       </footer>
# <p>
# <p>
#         9500 XC recordists! thanks for sharing everyone!
#        </p>
# </p>
# <section class="comments">
# <article>
# <div>
# <p>
#           dear friends,
#          </p>
# <p>
#           .....  and i get to be a bird friend.. and be one of them recordists XC ...
#           <strong>
#            many thanks to all!!
#           </strong>
# </p>
# </div>
# <footer>
#          bzcuhlA03n on June  3
#         </footer>
# </article>
# <p>
# <b>
#          1
#         </b>
#         replies ::
#         <img height="14" src="/static/img/discuss-light.png" width="14"/>
# <a href="https://xeno-canto.org/news/2104">
#          Your reply
#         </a>
# </p>
# </section>
# </article>
# <article>
# <footer>
#        May 17, 2023
#       </footer>
# <p>
# <p>
#         ... well, if you have not noticed something has changed, everything worked out fine :-)
#        </p>
# </p>
# <section class="comments">
# <article>
# <div>
# <p>
#           What the...the bats are there, cool!
#          </p>
# <p>
#           They must have been stealthily sneaked in during the night just like...well, bats themselves.
#          </p>
# </div>
# <footer>
#          Ulf Elman on May 17
#         </footer>
# </article>
# <article>
# <div>
# <p>
#           :-)
#          </p>
# </div>
# <footer>
#          Willem-Pier Vellinga on May 17
#         </footer>
# </article>
# <article>
# <div>
# <p>
#           Awesome! However, considering it's typically out of our hearing range, I wonder when we could have a section of our lovely amphibian neighbours, loud and sound XD
#          </p>
# </div>
# <footer>
#          Dave GUO on May 21
#         </footer>
# </article>
# <article>
# <div>
# <p>
#           Next on the list, Dave!
#          </p>
# </div>
# <footer>
#          Bob Planqué on May 21
#         </footer>
# </article>
# <article>
# <div>
# <p>
#           Not to jump on the bandwagon, but a mammal database would be superb. I have found very little reference material online with regard to mammals...
#          </p>
# </div>
# <footer>
#          Alan Dalton on May 23
#         </footer>
# </article>
# <article>
# <div>
# <p>
#           Also that's in the works, Alan. The mammal community seems to be a bit fragmented though, so it is harder to define a good set of metadata (in particular how to describe the sounds, the 'predefined sound types'). If you wish to help out, or know of others who might be able to do so, drop us a line at contact@...
#          </p>
# </div>
# <footer>
#          Bob Planqué on May 23
#         </footer>
# </article>
# <article>
# <div>
# <p>
#           Anura... Glad there's interest here.  I think there's probably enough of a scientific community to sustain and manage a collection... and also much interest among novices (like myself) to contribute. Maybe it'll inspire a PhD or two. What XC community has achieved on avifauna is beyond impressive. The addition of grasshoppers and bats is a nice surprise. Next step: Anurans.
#          </p>
# </div>
# <footer>
#          Greg Irving on May 28
#         </footer>
# </article>
# <article>
# <div>
# <p>
#           ... good to hear Greg :-) It's bit of a leap of faith, but let's just start out and see what will happen.
#          </p>
# </div>
# <footer>
#          Willem-Pier Vellinga on May 28
#         </footer>
# </article>
# <article>
# <div>
# <p>
#           Hi, everybody, when uploading bat sound files in particular, it's best to scale up the amplitude (by multiplying the wav file) if the sound intensity is very low. If not, the user won't see much in the spectrogram and has to scale up the amplitude by him/herself after downloading.
#          </p>
# </div>
# <footer>
#          Arjan Boonman on June  1
#         </footer>
# </article>
# <article>
# <div>
# <p>
#           As an Herpetologist, id love an Anura section????
#          </p>
# </div>
# <footer>
#          Simon Oberhofer on June  1
#         </footer>
# </article>
# <article>
# <div>
# <p>
#           ... see above :-) next in line Simon.
#          </p>
# </div>
# <footer>
#          Willem-Pier Vellinga on June  2
#         </footer>
# </article>
# <article>
# <div>
# <p>
#           Kinda missed that sorry - looking forward to it!
#          </p>
# </div>
# <footer>
#          Simon Oberhofer on June  5
#         </footer>
# </article>
# <article>
# <div>
# <p>
#           Primates - another excellent group to consider!
#          </p>
# </div>
# <footer>
#          Ding Li Yong on July 10
#         </footer>
# </article>
# <article>
# <div>
# <p>
#           Indeed, Ding Li. What we envisage is splitting the mammals in sea mammals and the others. We've already got a complete taxon list, working on establishing proper metadata for both groups.
#          </p>
# </div>
# <footer>
#          Willem-Pier Vellinga on July 12
#         </footer>
# </article>
# <p>
# <b>
#          14
#         </b>
#         replies ::
#         <img height="14" src="/static/img/discuss-light.png" width="14"/>
# <a href="https://xeno-canto.org/news/2103">
#          Your reply
#         </a>
# </p>
# </section>
# </article>
# <p>
# <a href="https://xeno-canto.org/news/archives">
#        Older news...
#       </a>
# </p>
# </section>
# <div class="column" id="latest">
# <section>
# <h1>
#        Random Recording
#       </h1>
# <div class="xc-audio">
# <div class="jp-type-single" data-xc-factor="" data-xc-filepath="//xeno-canto.org/sounds/uploaded/NWTKEXMKCA/XC815374-Common-Nightingale_Sarytogay8.mp3" data-xc-id="815374" id="xc_audio_815374_939">
# <div class="jp-xc-id">
# <table>
# <tr>
# <td>
# <a href="https://xeno-canto.org/815374">
#              XC815374
#             </a>
# <a href="https://xeno-canto.org/815374/download">
# <img height="14" src="/static/img/download.png" title="Download file 'XC815374 - Common Nightingale - Luscinia megarhynchos golzii.wav'" width="14"/>
# </a>
# </td>
# <td class="licenses">
# <a href="//creativecommons.org/licenses/by-nc-nd/4.0/" title="Creative Commons Attribution-NonCommercial-NoDerivs 4.0">
# <img height="14" src="/static/img/cc.png" width="14"/>
# <img height="14" src="/static/img/cc-by.png" width="14"/>
# <img height="14" src="/static/img/cc-nc.png" width="14"/>
# <img height="14" src="/static/img/cc-nd.png" width="14">
# </img>
# </a>
# </td>
# </tr>
# </table>
# </div>
# <div class="jp-xc-sono">
# <a class="fancybox" href="//xeno-canto.org/sounds/uploaded/NWTKEXMKCA/ffts/XC815374-large.png" rel="sono" title="XC815374: Common Nightingale (Luscinia megarhynchos golzii) by Ding Li Yong">
# <img class="spectro-image" src="//xeno-canto.org/sounds/uploaded/NWTKEXMKCA/ffts/XC815374-small.png"/>
# </a>
# <a class="fancybox" href="//xeno-canto.org/sounds/uploaded/NWTKEXMKCA/wave/XC815374-large.png" rel="sono" title="XC815374: Common Nightingale (Luscinia megarhynchos golzii) by Ding Li Yong">
# <img class="wave-image" src="//xeno-canto.org/sounds/uploaded/NWTKEXMKCA/wave/XC815374-small.png"/>
# </a>
# </div>
# <div class="jp-gui jp-interface">
# <ul class="jp-controls">
# <li>
# <a class="jp-play" href="javascript:;" tabindex="1">
#             play
#            </a>
# </li>
# <li>
# <a class="jp-pause" href="javascript:;" style="display:none;" tabindex="1">
#             pause
#            </a>
# </li>
# <li>
# <a class="jp-stop" href="javascript:;" tabindex="1">
#             stop
#            </a>
# </li>
# </ul>
# <div class="jp-progress">
# <div class="jp-seek-bar">
# <div class="jp-play-bar">
# </div>
# </div>
# </div>
# <div class="jp-time-holder">
# <div class="jp-current-time">
# </div>
# <div class="jp-xc-duration">
#            0:45
#           </div>
# </div>
# </div>
# <div class="jp-title" title="Common Nightingale Luscinia megarhynchos golzii - song">
# <span class="common-name">
#           Common Nightingale
#          </span>
#          (
#          <span class="sci-name">
#           Luscinia megarhynchos golzii
#          </span>
#          ) ·
#          <span class="jp-xc-call-type">
#           song
#          </span>
# </div>
# <div class="jp-xc-recordist">
#          Ding Li Yong
#         </div>
# <div class="jp-xc-location" title="Sarytogay, Uygur District, Almaty Province, Kazakhstan">
#          Sarytogay, Uygur District, Almaty Province, Kazakhstan
#         </div>
# </div>
# </div>
# <div>
#        ID incorrect?
#        <a href="https://xeno-canto.org/forum/topic/new?xcid=815374">
#         Tell us!
#        </a>
# </div>
# </section>
# <section class="tip">
# <h1>
#        Try this!
#       </h1>
# <h2>
#        Donation to Xeno-canto
#        <p>
#         As of september 2021 is possible to support XC with donations. Your contribution, small or large, will help us to keep the project flourishing and develop it in new directions. Please check out
#         <a href="https://www.xeno-canto.org/donate">
#          this page
#         </a>
#         .
#        </p>
# </h2>
# </section>
# <section class="article">
# <h1>
#        Latest Articles
#       </h1>
# <ul>
# <li>
# <a href="https://xeno-canto.org/article/281">
#          divergent weather..affairs at shown here  XC-ids in bobingen/bayern
#         </a>
#         by bzcuhlA03n
#        </li>
# <li>
# <a href="https://xeno-canto.org/article/280">
#          more or less well analyzed Tits of me
#         </a>
#         by bzcuhlA03n
#        </li>
# <li>
# <a href="https://xeno-canto.org/article/277">
#          Eurasian Pygmy Owl Glaucidium passerinum sound types
#         </a>
#         by Frank DD4WH
#        </li>
# <li>
# <a href="https://xeno-canto.org/article/275">
#          Weighted SNR as a more robust and precise tool in rating perceived recording sound quality A-E
#         </a>
#         by Ulf Elman
#        </li>
# <li>
# <a href="https://xeno-canto.org/article/274">
#          The Orthoptera update
#         </a>
#         by Bob Planqué
#        </li>
# <li>
# <a href="https://xeno-canto.org/articles">
#          More...
#         </a>
# </li>
# </ul>
# </section>
# <section>
# <h1>
#        Latest New Recordists
#       </h1>
# <ul>
# <li>
# <a href="https://xeno-canto.org/contributor/CDAUTFGECP">
#          Sachin Ranade
#         </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/contributor/PFWYEGCYYG">
#          Maximilian Grau
#         </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/contributor/ZSZFDZCBHD">
#          Armin Schwickardi
#         </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/contributor/PWHOCZMQAH">
#          Jeff Smith
#         </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/contributor/WCBTUPIVXJ">
#          Laure Pellicier
#         </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/contributor/IWOFEKTGLS">
#          Sylvain
#         </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/contributor/JDMPETCXMM">
#          Brad Mowers
#         </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/contributor/QITOBYMBYQ">
#          Beat Lang
#         </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/contributor/SQQCAMAQDL">
#          Ewa Grunditz Lilliesköld
#         </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/contributor/PSDEBCPZOI">
#          Evi &amp; Hauke Clausen-Schaumann
#         </a>
# </li>
# <li>
#         Welcome!
#        </li>
# </ul>
# </section>
# </div>
# </div>
# <div class="column" id="secondary-content">
# <form method="get">
# <select class="unified-dropdown" name="gid" onchange="this.form.submit();">
# <option value="0">
#        All groups
#       </option>
# <option value="1">
#        Birds
#       </option>
# <option value="2">
#        Grasshoppers
#       </option>
# <option value="3">
#        Bats
#       </option>
# </select>
# </form>
# <section>
# <h1>
#       Collection Statistics
#      </h1>
# <table class="key-value">
# <tbody>
# <tr>
# <td>
#          1344902
#         </td>
# <td>
#          IDs
#         </td>
# </tr>
# <tr>
# <td>
#          776420
#         </td>
# <td>
#          Recordings
#         </td>
# </tr>
# <tr>
# <td>
#          10945
#         </td>
# <td>
# <a href="https://www.worldbirdnames.org" target="_blank">
#           Species
#          </a>
# </td>
# </tr>
# <tr>
# <td>
#          12286
#         </td>
# <td>
#          Subspecies
#         </td>
# </tr>
# <tr>
# <td>
#          9626
#         </td>
# <td>
#          Recordists
#         </td>
# </tr>
# <tr>
# <td>
#          11232:32:52
#         </td>
# <td>
#          Recording Time
#         </td>
# </tr>
# <tr>
# <td>
#          683260
#         </td>
# <td>
# <a href="https://doi.org/10.15468/qv0ksn" target="_blank">
#           Records to GBIF
#          </a>
# </td>
# </tr>
# </tbody>
# </table>
# <p>
# <a href="https://xeno-canto.org/collection/">
#        More...
#       </a>
# </p>
# </section>
# <section>
# <h1>
#       Latest New Species
#      </h1>
# <ul>
# <li>
# <a href="https://xeno-canto.org/species/Diphylla-ecaudata">
#         Hairy-legged Vampire Bat
#        </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/species/Pteronotus-gymnonotus">
#         Big Naked-backed Bat
#        </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/species/Vampyressa-thyone">
#         Northern Little Yellow-eared Bat
#        </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/species/Trinycteris-nicefori">
#         Niceforo's Big-eared Bat
#        </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/species/Trachops-cirrhosus">
#         Fringe-lipped Bat
#        </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/collection/species/latest">
#         More...
#        </a>
# </li>
# </ul>
# </section>
# <section class="recording" id="latest-additions">
# <h1>
#       Latest Additions
#      </h1>
# <ul>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819348_611" preload="metadata" src="//xeno-canto.org/sounds/uploaded/ZNHUUXHXZS/XC819348-ste_202307_27_28_yom_0143V.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819348_611" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819348">
#         XC819348
#        </a>
#        :
#        <a href="https://xeno-canto.org/species/Sterna-hirundo">
#         Common Tern
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/ZNHUUXHXZS">
#         Juha Saari
#        </a>
#        from Finland
#       </li>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819347_612" preload="metadata" src="//xeno-canto.org/sounds/uploaded/XKJTIUSQNM/XC819347-Vervain-Hummingbird-male-2.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="red" id="btn_xc_audio_819347_612" title="Ultrasonic, high frequency sound recording">
# <img src="/static/img/play-red.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819347">
#         XC819347
#        </a>
#        :
#        <a href="https://xeno-canto.org/species/Mellisuga-minima">
#         Vervain Hummingbird
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/XKJTIUSQNM">
#         Johan Chaves
#        </a>
#        from Dominican Republic
#       </li>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819346_613" preload="metadata" src="//xeno-canto.org/sounds/uploaded/FDRIKEROUW/XC819346-Tettigonia-viridissima.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819346_613" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819346">
#         XC819346
#        </a>
#        :
#        <a href="https://xeno-canto.org/species/Tettigonia-viridissima">
#         Great Green Bush-cricket
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/FDRIKEROUW">
#         Francesco Barberini
#        </a>
#        from Italy
#       </li>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819345_614" preload="metadata" src="//xeno-canto.org/sounds/uploaded/FDRIKEROUW/XC819345-Civetta-2.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819345_614" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819345">
#         XC819345
#        </a>
#        :
#        <a href="https://xeno-canto.org/species/Athene-noctua">
#         Little Owl
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/FDRIKEROUW">
#         Francesco Barberini
#        </a>
#        from Italy
#       </li>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819344_615" preload="metadata" src="//xeno-canto.org/sounds/uploaded/FROVFAFTMA/XC819344-20230707-1622-长风公园-棕头鸦雀begging-dr100m3.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819344_615" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819344">
#         XC819344
#        </a>
#        :
#        <a href="https://xeno-canto.org/species/Sinosuthora-webbiana">
#         Vinous-throated Parrotbill
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/FROVFAFTMA">
#         Ray Tsu 诸仁
#        </a>
#        from China
#       </li>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819343_616" preload="metadata" src="//xeno-canto.org/sounds/uploaded/XOZRUGOUNS/XC819343-chant.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819343_616" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819343">
#         XC819343
#        </a>
#        : Identity unknown by
#        <a href="https://xeno-canto.org/contributor/XOZRUGOUNS">
#         Simon Girard
#        </a>
#        from Canada
#       </li>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819341_617" preload="metadata" src="//xeno-canto.org/sounds/uploaded/YNUCLEIZAR/XC819341-skovsanger.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819341_617" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819341">
#         XC819341
#        </a>
#        :
#        <a href="https://xeno-canto.org/species/Phylloscopus-sibilatrix">
#         Wood Warbler
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/YNUCLEIZAR">
#         Simon S. Christiansen
#        </a>
#        from Denmark
#       </li>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819340_618" preload="metadata" src="//xeno-canto.org/sounds/uploaded/YNUCLEIZAR/XC819340-nordsanger.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819340_618" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819340">
#         XC819340
#        </a>
#        :
#        <a href="https://xeno-canto.org/species/Phylloscopus-borealis">
#         Arctic Warbler
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/YNUCLEIZAR">
#         Simon S. Christiansen
#        </a>
#        from Sweden
#       </li>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819339_619" preload="metadata" src="//xeno-canto.org/sounds/uploaded/YNUCLEIZAR/XC819339-230626_0243.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819339_619" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819339">
#         XC819339
#        </a>
#        :
#        <a href="https://xeno-canto.org/species/Poecile-cinctus">
#         Grey-headed Chickadee
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/YNUCLEIZAR">
#         Simon S. Christiansen
#        </a>
#        from Sweden
#       </li>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819338_620" preload="metadata" src="//xeno-canto.org/sounds/uploaded/JXZFXAZWHY/XC819338-23.05.2023---18.45---P.major.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819338_620" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819338">
#         XC819338
#        </a>
#        :
#        <a href="https://xeno-canto.org/species/Parus-major">
#         Great Tit
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/JXZFXAZWHY">
#         Grzegorz Lorek
#        </a>
#        from Poland
#       </li>
# <li>
# <a href="https://xeno-canto.org/explore?query=since:31&amp;dir=0&amp;order=xc">
#         More...
#        </a>
# </li>
# </ul>
# <p>
#       Great work!
#      </p>
# </section>
# <section class="recording">
# <h1>
#       Latest Mysteries
#      </h1>
# <ul>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819343_875" preload="metadata" src="//xeno-canto.org/sounds/uploaded/XOZRUGOUNS/XC819343-chant.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819343_875" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819343">
#         XC819343
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/XOZRUGOUNS">
#         Simon Girard
#        </a>
#        from Canada
#       </li>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819315_876" preload="metadata" src="//xeno-canto.org/sounds/uploaded/JEBCJWAMTY/XC819315-Bird-in-Abeokuta-1-%281%29.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819315_876" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819315">
#         XC819315
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/JEBCJWAMTY">
#         Ololade
#        </a>
#        from Nigeria
#       </li>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819314_877" preload="metadata" src="//xeno-canto.org/sounds/uploaded/JEBCJWAMTY/XC819314-Abeokuta-bird-6-20-%282%29.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819314_877" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819314">
#         XC819314
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/JEBCJWAMTY">
#         Ololade
#        </a>
#        from Nigeria
#       </li>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819238_878" preload="metadata" src="//xeno-canto.org/sounds/uploaded/RZQIVYUMAU/XC819238-mystere-2.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819238_878" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819238">
#         XC819238
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/RZQIVYUMAU">
#         Nicolas MOKUENKO
#        </a>
#        from France
#       </li>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819237_879" preload="metadata" src="//xeno-canto.org/sounds/uploaded/RZQIVYUMAU/XC819237-mystere-2.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819237_879" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819237">
#         XC819237
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/RZQIVYUMAU">
#         Nicolas MOKUENKO
#        </a>
#        from France
#       </li>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819208_880" preload="metadata" src="//xeno-canto.org/sounds/uploaded/SAECDVMCUB/XC819208-macreuse.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819208_880" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819208">
#         XC819208
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/SAECDVMCUB">
#         Sébastien Arriubergé
#        </a>
#        from France
#       </li>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819201_881" preload="metadata" src="//xeno-canto.org/sounds/uploaded/PJVICFDZGZ/XC819201-230607_1751_1800_A_M-sulfureopectus_NNLN.wav">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819201_881" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819201">
#         XC819201
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/PJVICFDZGZ">
#         Antonio Xeira
#        </a>
#        from Guinea-Bissau
#       </li>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819196_882" preload="metadata" src="//xeno-canto.org/sounds/uploaded/KTBQONMNPE/XC819196-Poss-McCall-s-Screech-Owl-Young-BRGSP.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819196_882" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819196">
#         XC819196
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/KTBQONMNPE">
#         MiriamEaglemon
#        </a>
#        from United States
#       </li>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819161_883" preload="metadata" src="//xeno-canto.org/sounds/uploaded/PFWYEGCYYG/XC819161-AUD-20230725-WA0010.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819161_883" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819161">
#         XC819161
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/PFWYEGCYYG">
#         Maximilian Grau
#        </a>
#        from Germany
#       </li>
# <li>
# <div class="xc-mini-audio">
# <audio class="xc-mini-player" id="xc_audio_819149_884" preload="metadata" src="//xeno-canto.org/sounds/uploaded/BJKTMHQQHM/XC819149-Voice-0084-1-MP3.mp3">
# </audio>
# <button class="xc-mini-player" data-icon="black" id="btn_xc_audio_819149_884" title="">
# <img src="/static/img/play-black.svg"/>
# </button>
# </div>
# <a href="https://xeno-canto.org/819149">
#         XC819149
#        </a>
#        by
#        <a href="https://xeno-canto.org/contributor/BJKTMHQQHM">
#         Gordon Nichols
#        </a>
#        from Australia
#       </li>
# <li>
# <a href="https://xeno-canto.org/mysteries">
#         More...
#        </a>
# </li>
# </ul>
# </section>
# </div>
# </div>
# <footer>
# <div>
# <table>
# <tr>
# <td>
# <p>
#         Xeno-canto.org is powered by the Xeno-canto Foundation and Naturalis Biodiversity Center
#        </p>
# <p>
# <a href="//www.naturalis.nl/" target="_blank">
# <img alt="Naturalis Biodiversity Center" height="80" src="/static/img/naturalis_logo.png" width="147"/>
# </a>
# </p>
# <p>
#         Website © 2005-2023
#         <b>
#          Xeno-canto Foundation
#         </b>
# </p>
# <p id="license">
#         Recordings © the recordist. See recording details for license information.
#        </p>
# <p id="license">
#         Sonogram images ©
#         <b>
#          Xeno-canto Foundation
#         </b>
#         . Sonogram images share the same license terms as the recording they depict.
#        </p>
# <p>
# <a href="https://xeno-canto.org/about/terms">
#          Terms of use
#         </a>
# </p>
# <p>
# <a href="https://xeno-canto.org/about/credits">
#          Credits
#         </a>
# </p>
# </td>
# <td>
# <ul class="simple">
# <li>
# <a href="//www.facebook.com/xenocanto">
# <img class="icon" height="24" src="/static/img/facebook.png" width="24"/>
#           Like us on Facebook
#          </a>
# </li>
# <li>
# <a href="//www.twitter.com/xenocanto">
# <img class="icon" height="24" src="/static/img/twitter.png" width="24"/>
#           Follow us on Twitter
#          </a>
# </li>
# <li>
# <a href="//www.youtube.com/channel/UC8At4qJ5678S3IX8_n7mstg">
# <img class="icon" height="24" src="/static/img/youtube.png" width="24"/>
#           Find us on YouTube
#          </a>
# </li>
# <li>
# <script type="text/javascript">
#           document.write("<n uers=\"znvygb:pbagnpg@krab-pnagb.bet?fhowrpg=Pbagnpg%20krab-pnagb\" ery=\"absbyybj\"><vzt pynff='vpba' jvqgu='24' urvtug='24' fep='/fgngvp/vzt/znvy-24.cat'> Pbagnpg hf ivn rznvy</n>".replace(/[a-zA-Z]/g,
#         function(c){return String.fromCharCode((c<="Z"?90:122)>=(c=c.charCodeAt(0)+13)?c:c-26);}))
#          </script>
# </li>
# <li style="margin-top: 30px;">
# <a href="https://xeno-canto.org/donate">
# <img alt="Donate to Xeno-canto" src="https://www.paypalobjects.com/en_US/NL/i/btn/btn_donateCC_LG.gif"/>
# </a>
# </li>
# </ul>
# </td>
# <td>
# <ul id="languages">
# <li>
# <a href="https://xeno-canto.org/lang/af" rel="nofollow">
#           Afrikaans
#          </a>
#          *
#         </li>
# <li>
# <a href="https://xeno-canto.org/lang/ca" rel="nofollow">
#           Català
#          </a>
#          *
#         </li>
# <li>
# <a href="https://xeno-canto.org/lang/cs" rel="nofollow">
#           Česky
#          </a>
#          *
#         </li>
# <li>
# <a href="https://xeno-canto.org/lang/da" rel="nofollow">
#           Dansk
#          </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/lang/de" rel="nofollow">
#           Deutsch
#          </a>
# </li>
# <li class="selected">
# <a href="https://xeno-canto.org/lang/en" rel="nofollow">
#           English
#          </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/lang/es" rel="nofollow">
#           Español
#          </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/lang/et" rel="nofollow">
#           Eesti
#          </a>
#          *
#         </li>
# <li>
# <a href="https://xeno-canto.org/lang/fi" rel="nofollow">
#           Suomi
#          </a>
#          *
#         </li>
# <li>
# <a href="https://xeno-canto.org/lang/fr" rel="nofollow">
#           Français
#          </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/lang/hu" rel="nofollow">
#           Magyar
#          </a>
#          *
#         </li>
# <li>
# <a href="https://xeno-canto.org/lang/id" rel="nofollow">
#           Bahasa Indonesia
#          </a>
#          *
#         </li>
# <li>
# <a href="https://xeno-canto.org/lang/is" rel="nofollow">
#           Íslenska
#          </a>
#          *
#         </li>
# <li>
# <a href="https://xeno-canto.org/lang/it" rel="nofollow">
#           Italiano
#          </a>
#          *
#         </li>
# <li>
# <a href="https://xeno-canto.org/lang/ja" rel="nofollow">
#           日本語
#          </a>
#          *
#         </li>
# <li>
# <a href="https://xeno-canto.org/lang/lt" rel="nofollow">
#           Lietuvių
#          </a>
#          *
#         </li>
# <li>
# <a href="https://xeno-canto.org/lang/lv" rel="nofollow">
#           Latviešu
#          </a>
#          *
#         </li>
# <li>
# <a href="https://xeno-canto.org/lang/nl" rel="nofollow">
#           Nederlands
#          </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/lang/no" rel="nofollow">
#           Norsk
#          </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/lang/pl" rel="nofollow">
#           Polski
#          </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/lang/pt" rel="nofollow">
#           Português
#          </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/lang/pt_BR" rel="nofollow">
#           Português do Brasil
#          </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/lang/ru" rel="nofollow">
#           Русский
#          </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/lang/se" rel="nofollow">
#           Davvisámegiella
#          </a>
#          *
#         </li>
# <li>
# <a href="https://xeno-canto.org/lang/si" rel="nofollow">
#           Slovenčina
#          </a>
#          *
#         </li>
# <li>
# <a href="https://xeno-canto.org/lang/sl" rel="nofollow">
#           Slovenščina
#          </a>
#          *
#         </li>
# <li>
# <a href="https://xeno-canto.org/lang/sv" rel="nofollow">
#           Svenska
#          </a>
# </li>
# <li>
# <a href="https://xeno-canto.org/lang/th" rel="nofollow">
#           ภาษาไทย
#          </a>
#          *
#         </li>
# <li>
# <a href="https://xeno-canto.org/lang/uk" rel="nofollow">
#           Українська
#          </a>
#          *
#         </li>
# <li>
# <a href="https://xeno-canto.org/lang/zh_CN" rel="nofollow">
#           简体中文
#          </a>
#          *
#         </li>
# <li>
# <a href="https://xeno-canto.org/lang/zh_TW" rel="nofollow">
#           繁體中文
#          </a>
# </li>
# </ul>
# <p>
#         * Only species names are translated
#        </p>
# </td>
# </tr>
# </table>
# </div>
# </footer>
# <script type="text/javascript">
#    jQuery(document).ready(
#                 function () {
#                     // set up collapsible 'read more' sections
#                     jQuery('.readmore').expander({slicePoint:40, expandText:'more&nbsp;&raquo;', userCollapseText: '&laquo;&nbsp;less', widow: 2 });
#                 }
#             );
#   </script>
# <script type="text/javascript">
#    var _gaq = _gaq || [];
#             _gaq.push(['_setAccount', 'UA-324458-1']);
#             _gaq.push(['_trackPageview']);
#
#             (function () {
#                 var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#                 ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#                 var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#             })();
#   </script>
# <script src="/static/js/jplayer/jquery.jplayer.min.js" type="text/javascript">
# </script>
# <script src="/static/js/jplayer/xcplayer.js?v3-0-1" type="text/javascript">
# </script>
# <script src="/static/js/jquery.autocomplete-min.js" type="text/javascript">
# </script>
# <script src="/static/js/jquery.placeholder.min.js" type="text/javascript">
# </script>
# <script src="/static/js/jquery.expander.min.js" type="text/javascript">
# </script>
# <script src="/static/js/jquery.fancybox.pack.js" type="text/javascript">
# </script>
# <script src="/static/js/jquery.qtip.min.js" type="text/javascript">
# </script>
# <script src="/static/js/rate-recording.js?v3-0-1" type="text/javascript">
# </script>
# <script src="/static/js/hoverIntent.js" type="text/javascript">
# </script>
# <script src="/static/js/superfish.js" type="text/javascript">
# </script>
# <script src="/static/js/xc-generic.js?v3-0-1" type="text/javascript">
# </script>
# </body>
# </html>

# %%
title = soup2.find('title')
print(title)
# Out:
# <title>
#    xeno-canto :: Sharing wildlife sounds from around the world
#   </title>

# %%
def extract_data():
    base_url = "https://xeno-canto.org"
    url = f"{base_url}/species/browse.php"

    bird_data = []

    while url:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, "html.parser")

        for row in soup.select(".species-list .species"):
            species_name = row.select_one("a").text.strip()
            family_name = row.select_one(".family").text.strip()

            # extracting the subspecies, latest species, latest articles,
            # location, date, recordists, and recording time (if available).
            subspecies = row.select_one(".subspecies").text.strip()
            latest_species = row.select_one(".latest_species").text.strip()
            latest_articles = row.select_one(".latest_articles").text.strip()
            location = row.select_one(".location").text.strip()
            date = row.select_one(".date").text.strip()
            recordists = row.select_one(".recordist").text.strip()
            recording_time = row.select_one(".time").text.strip()

            # Extract the species' taxonomy (order, family, genus, species)
            taxonomy = [item.text.strip() for item in row.select(".taxonomy a")]

            bird_data.append({
                "Species": species_name,
                "Family": family_name,
                "Subspecies": subspecies,
                "Latest Species": latest_species,
                "Latest Articles": latest_articles,
                "Location": location,
                "Date": date,
                "Recordists": recordists,
                "Recording Time": recording_time,
                "Taxonomy": ", ".join(taxonomy),  # Convert taxonomy list to a comma-separated string
            })

        next_page = soup.select_one("li.next a")
        url = base_url + next_page["href"] if next_page else None
        
    print(bird_data)

    return bird_data

def save_to_csv(data, filename):
    keys = data[0].keys() if data else []
    with open(filename, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=keys)
        writer.writeheader()
        writer.writerows(data)

if __name__ == "__main__":
    bird_data = extract_data()

    # Print the list of bird species data before saving to CSV
    print("Bird Species Data:")
    for bird in bird_data:
        print(bird)

    # Save the bird species data to CSV
    save_to_csv(bird_data, "bird_excel.csv")
    print("CSV file generated successfully.")
# Out:
# []
# Bird Species Data:
# CSV file generated successfully.

# %%
def extract_bird_songs():
    base_url = "https://xeno-canto.org/api/2/recordings"
    bird_songs = []

    page = 1
    while True:
        params = {"query": "q", "page": page}
        response = requests.get(base_url, params=params)

        if response.status_code != 200:
            break

        data = response.json()
        if not data["recordings"]:
            break

        bird_songs.extend(data["recordings"])
        page += 1

    return bird_songs

if __name__ == "__main__":
    bird_songs_data = extract_bird_songs()
    print(f"Total bird songs extracted: {len(bird_songs_data)}")

    # Print the first few entries to get an idea of the data structure
    print(bird_songs_data[:10])
# Out:
# Total bird songs extracted: 9736
# [{'id': '676311', 'gen': 'Grallaria', 'sp': 'saturata', 'ssp': '', 'group': 'birds', 'en': 'Equatorial Antpitta', 'rec': 'Galo Real', 'cnt': 'Ecuador', 'loc': 'Papallacta, Quijos, Napo', 'lat': '-0.3766', 'lng': '-78.1603', 'alt': '3400', 'type': '', 'sex': 'male', 'stage': 'adult', 'method': 'field recording', 'url': '//xeno-canto.org/676311', 'file': 'https://xeno-canto.org/676311/download', 'file-name': 'XC676311-Equatorial Antpitta .mp3', 'sono': {'small': '//xeno-canto.org/sounds/uploaded/GHVYOJSPRJ/ffts/XC676311-small.png', 'med': '//xeno-canto.org/sounds/uploaded/GHVYOJSPRJ/ffts/XC676311-med.png', 'large': '//xeno-canto.org/sounds/uploaded/GHVYOJSPRJ/ffts/XC676311-large.png', 'full': '//xeno-canto.org/sounds/uploaded/GHVYOJSPRJ/ffts/XC676311-full.png'}, 'osci': {'small': '//xeno-canto.org/sounds/uploaded/GHVYOJSPRJ/wave/XC676311-small.png', 'med': '//xeno-canto.org/sounds/uploaded/GHVYOJSPRJ/wave/XC676311-med.png', 'large': '//xeno-canto.org/sounds/uploaded/GHVYOJSPRJ/wave/XC676311-large.png'}, 'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/', 'q': 'A', 'length': '0:37', 'time': '13:30', 'date': '2011-03-09', 'uploaded': '2021-09-22', 'also': [], 'rmk': '', 'bird-seen': 'yes', 'animal-seen': 'yes', 'playback-used': 'no', 'temp': '', 'regnr': '', 'auto': 'no', 'dvc': '', 'mic': '', 'smp': '44100'}, {'id': '666766', 'gen': 'Grallaria', 'sp': 'saturata', 'ssp': '', 'group': 'birds', 'en': 'Equatorial Antpitta', 'rec': 'Leonardo Ordóñez-Delgado', 'cnt': 'Ecuador', 'loc': 'Reserva Numbala, Palanda, Zamora Chinchipe', 'lat': '-4.4051', 'lng': '-79.0893', 'alt': '2900', 'type': 'song', 'sex': 'uncertain', 'stage': 'uncertain', 'method': 'field recording', 'url': '//xeno-canto.org/666766', 'file': 'https://xeno-canto.org/666766/download', 'file-name': 'XC666766-080007 Grallaria rufula XC.mp3', 'sono': {'small': '//xeno-canto.org/sounds/uploaded/RJNSQXBIJE/ffts/XC666766-small.png', 'med': '//xeno-canto.org/sounds/uploaded/RJNSQXBIJE/ffts/XC666766-med.png', 'large': '//xeno-canto.org/sounds/uploaded/RJNSQXBIJE/ffts/XC666766-large.png', 'full': '//xeno-canto.org/sounds/uploaded/RJNSQXBIJE/ffts/XC666766-full.png'}, 'osci': {'small': '//xeno-canto.org/sounds/uploaded/RJNSQXBIJE/wave/XC666766-small.png', 'med': '//xeno-canto.org/sounds/uploaded/RJNSQXBIJE/wave/XC666766-med.png', 'large': '//xeno-canto.org/sounds/uploaded/RJNSQXBIJE/wave/XC666766-large.png'}, 'lic': '//creativecommons.org/licenses/by-nc-nd/4.0/', 'q': 'A', 'length': '1:38', 'time': '07:00', 'date': '2021-06-07', 'uploaded': '2021-08-07', 'also': [], 'rmk': '', 'bird-seen': 'no', 'animal-seen': 'no', 'playback-used': 'no', 'temp': '', 'regnr': '', 'auto': 'no', 'dvc': '', 'mic': '', 'smp': '44100'}, {'id': '506969', 'gen': 'Grallaria', 'sp': 'saturata', 'ssp': '', 'group': 'birds', 'en': 'Equatorial Antpitta', 'rec': 'David Monroy Rengifo', 'cnt': 'Colombia', 'loc': 'Road to Nevado del Ruiz, above Manizales, Caldas, C Andes', 'lat': '4.9992', 'lng': '-75.3484', 'alt': '3700', 'type': 'song', 'sex': 'uncertain', 'stage': '', 'method': 'field recording', 'url': '//xeno-canto.org/506969', 'file': 'https://xeno-canto.org/506969/download', 'file-name': 'XC506969-170508461.mp3', 'sono': {'small': '//xeno-canto.org/sounds/uploaded/MAVGCHPXII/ffts/XC506969-small.png', 'med': '//xeno-canto.org/sounds/uploaded/MAVGCHPXII/ffts/XC506969-med.png', 'large': '//xeno-canto.org/sounds/uploaded/MAVGCHPXII/ffts/XC506969-large.png', 'full': '//xeno-canto.org/sounds/uploaded/MAVGCHPXII/ffts/XC506969-full.png'}, 'osci': {'small': '//xeno-canto.org/sounds/uploaded/MAVGCHPXII/wave/XC506969-small.png', 'med': '//xeno-canto.org/sounds/uploaded/MAVGCHPXII/wave/XC506969-med.png', 'large': '//xeno-canto.org/sounds/uploaded/MAVGCHPXII/wave/XC506969-large.png'}, 'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/', 'q': 'A', 'length': '0:11', 'time': '08:30', 'date': '2019-07-27', 'uploaded': '2019-11-15', 'also': [], 'rmk': '', 'bird-seen': 'yes', 'animal-seen': 'yes', 'playback-used': 'no',  ...

# %%
df = pd.DataFrame(bird_data)
df.to_csv('bird_species.csv')
df.to_excel('bird_species.xlsx')
print('Saved to file')
# Out:
# Saved to file

# %%
def extract_location_data():
    url = "https://xeno-canto.org"
    response = requests.get(url)
    bsobj = BeautifulSoup(response.content, 'html.parser')

    bird_list = bsobj.select('.species-list .species')

    if not bird_list:
        print("No bird data found. Please check the website's structure or try again later.")
        return

    for bird in bird_list:
        location_element = bird.select_one(".location")
        date_element = bird.select_one(".date")
        time_element = bird.select_one(".time")

        if location_element and date_element and time_element:
            location = location_element.text.strip()
            date = date_element.text.strip()
            recording_time = time_element.text.strip()

            print(f"Location: {location}, Date: {date}, Time: {recording_time}")
        else:
            print("Incomplete data for a bird recording. Skipping this entry.")

if __name__ == "__main__":
    extract_location_data()
# Out:
# No bird data found. Please check the website's structure or try again later.
